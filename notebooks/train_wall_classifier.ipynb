# %% [markdown]
# # Покрытия стен: DINOv2 с поиском признаков гипсокартона
#
# SegFormer выделяет стену. DINOv2 анализирует всю стену в разрешении 448×448 и девять участков сетки 3×3. Attention и max-pooling сохраняют редкие признаки вроде швов и саморезов. Дополнительная бинарная голова отдельно проверяет `drywall / not_drywall`.

# %%
from pathlib import Path
import base64, hashlib, json, random, re, shutil
import numpy as np
import pandas as pd
import torch
import torch.nn.functional as F
from PIL import Image, ImageOps, ImageDraw
from torchvision import models, transforms
from torch.utils.data import Dataset, DataLoader, WeightedRandomSampler
from transformers import AutoImageProcessor, AutoModel, SegformerForSemanticSegmentation
from sklearn.model_selection import train_test_split
from sklearn.metrics import classification_report, confusion_matrix, accuracy_score, f1_score
from scipy import ndimage
import matplotlib.pyplot as plt

PROJECT = Path('/Users/himynameisartem/Documents/Development/ML/Renovation_calculator_CV')
DATA = PROJECT / 'data/dataset/walls'
OUT = PROJECT / 'outputs/wall_training/current'
OUT.mkdir(parents=True, exist_ok=True)

EXPECTED_CLASSES = {'bare_unfinished_wall', 'exposed_drywall', 'unfinished_plaster_or_putty', 'wallpaper', 'tile', 'rigid_decorative_cladding'}
SEED = 42
INPUT_SIZE = 384
MAX_WALL_VIEWS_PER_IMAGE = 3
LOCAL_VIEWS_PER_WALL = 9
LOCAL_INPUT_SIZE = 320
MIN_COMPONENT_AREA = 0.03
random.seed(SEED); np.random.seed(SEED); torch.manual_seed(SEED)
device = torch.device('mps' if torch.backends.mps.is_available() else 'cpu')
print('Device:', device)
print('Classes:', sorted(EXPECTED_CLASSES))
print('Results:', OUT)
# Out:
# Device: mps
# Classes: ['bare_unfinished_wall', 'exposed_drywall', 'rigid_decorative_cladding', 'tile', 'unfinished_plaster_or_putty', 'wallpaper']
# Results: /Users/himynameisartem/Documents/Development/ML/Renovation_calculator_CV/outputs/wall_training/current

# %% [markdown]
# ## 1. Исходные фотографии и разделение 70/15/15
#
# Точные дубликаты удаляются. Кадры одного объявления определяются по префиксу имени файла и целиком попадают только в train, validation или test.

# %%
extensions = {'.jpg','.jpeg','.png','.webp','.bmp','.tif','.tiff'}
rows, unreadable = [], []
actual_classes = {folder.name for folder in DATA.iterdir() if folder.is_dir()}
assert actual_classes == EXPECTED_CLASSES, f'Ожидались {sorted(EXPECTED_CLASSES)}, найдены {sorted(actual_classes)}'

for folder in sorted(DATA.iterdir()):
    for path in sorted(folder.rglob('*')):
        if not path.is_file() or path.suffix.lower() not in extensions:
            continue
        try:
            with Image.open(path) as source:
                image = ImageOps.exif_transpose(source).convert('RGB')
                digest = hashlib.sha256(f'{image.width}x{image.height}:'.encode() + image.tobytes()).hexdigest()
            filename = path.name.lower()
            listing_match = re.match(r'^([0-9a-f]{40})_', filename)
            reddit_match = re.match(r'^(.*?)-v0-', filename)
            if listing_match:
                group_key = listing_match.group(1)
            elif reddit_match:
                group_key = reddit_match.group(1)
            else:
                group_key = digest
            rows.append({
                'path': str(path.resolve()),
                'label': folder.name,
                'source_id': digest,
                'group_id': f'{folder.name}:{group_key}',
            })
        except (OSError, ValueError) as error:
            unreadable.append({'path':str(path), 'reason':str(error)})

raw = pd.DataFrame(rows)
assert len(raw), 'Нет читаемых изображений'
conflicting_ids = set(raw.groupby('source_id').label.nunique().loc[lambda x:x > 1].index)
raw[raw.source_id.isin(conflicting_ids)].to_csv(OUT/'conflicting_labels.csv', index=False)
pd.DataFrame(unreadable).to_csv(OUT/'unreadable.csv', index=False)
sources = raw[~raw.source_id.isin(conflicting_ids)].drop_duplicates('source_id').copy()
assert set(sources.label) == EXPECTED_CLASSES
assert sources.groupby('label').size().min() >= 10, 'В одном из классов меньше 10 исходных фото'
classes = sorted(EXPECTED_CLASSES)

groups = sources[['group_id','label']].drop_duplicates().reset_index(drop=True)
assert groups.groupby('group_id').label.nunique().max() == 1
train_groups, remainder_groups = train_test_split(
    groups, test_size=.30, stratify=groups.label, random_state=SEED
)
val_groups, test_groups = train_test_split(
    remainder_groups, test_size=.50, stratify=remainder_groups.label, random_state=SEED
)
group_split = pd.concat([
    train_groups.assign(split='train'),
    val_groups.assign(split='val'),
    test_groups.assign(split='test'),
], ignore_index=True)
source_manifest = sources.merge(group_split[['group_id','split']], on='group_id', how='left')
assert source_manifest.split.notna().all()
assert source_manifest.source_id.is_unique
assert source_manifest.groupby('group_id').split.nunique().max() == 1
source_manifest.to_csv(OUT/'source_split.csv', index=False)
display(pd.crosstab(source_manifest.label, source_manifest.split).reindex(columns=['train','val','test']))
display(pd.crosstab(group_split.label, group_split.split).reindex(columns=['train','val','test']))
print('Sources:', len(source_manifest), 'Groups:', len(group_split), 'Classes:', classes)
# Out:
# split                        train  val  test
# label
# bare_unfinished_wall            88   24    22
# exposed_drywall                 75   22    21
# rigid_decorative_cladding       95   17    23
# tile                            84   24    18
# unfinished_plaster_or_putty    112   16    18
# wallpaper                       92   13    16
# split                        train  val  test
# label
# bare_unfinished_wall            14    3     3
# exposed_drywall                 38    8     9
# rigid_decorative_cladding       79   17    17
# tile                            42    9     9
# unfinished_plaster_or_putty     21    4     5
# wallpaper                       17    4     3
# Sources: 780 Groups: 302 Classes: ['bare_unfinished_wall', 'exposed_drywall', 'rigid_decorative_cladding', 'tile', 'unfinished_plaster_or_putty', 'wallpaper']

# %% [markdown]
# ## 2. Крупные стены и локальные фрагменты
#
# SegFormer создаёт маску стены. Для каждой крупной связной области сохраняются её границы и координаты четырёх локальных участков с высокой долей стены. Отдельные изображения на диск не записываются.

# %%
segmenter_name = 'nvidia/segformer-b0-finetuned-ade-512-512'
processor = AutoImageProcessor.from_pretrained(segmenter_name)
segmenter = SegformerForSemanticSegmentation.from_pretrained(segmenter_name).to(device).eval()
wall_id = next(int(k) for k,v in segmenter.config.id2label.items() if v == 'wall')

def box_iou(a,b):
    ax0,ay0,ax1,ay1=a; bx0,by0,bx1,by1=b
    intersection=max(0,min(ax1,bx1)-max(ax0,bx0))*max(0,min(ay1,by1)-max(ay0,by0))
    union=(ax1-ax0)*(ay1-ay0)+(bx1-bx0)*(by1-by0)-intersection
    return intersection/union if union else 0

def encode_small_mask(mask, max_side=160):
    image=Image.fromarray((mask.astype(np.uint8)*255),mode='L')
    scale=min(1.0,max_side/max(image.size))
    size=(max(1,round(image.width*scale)),max(1,round(image.height*scale)))
    image=image.resize(size,Image.Resampling.NEAREST)
    binary=np.asarray(image)>=128
    packed=np.packbits(binary.reshape(-1))
    return base64.b64encode(packed.tobytes()).decode('ascii'),binary.shape[0],binary.shape[1]

def decode_mask(mask_data,height,width,output_size):
    packed=np.frombuffer(base64.b64decode(mask_data),dtype=np.uint8)
    mask=np.unpackbits(packed,count=int(height)*int(width)).reshape(int(height),int(width))
    return Image.fromarray((mask*255).astype(np.uint8),mode='L').resize(output_size,Image.Resampling.NEAREST)

def select_local_boxes(component,offset_x,offset_y,sx,sy):
    h,w=component.shape
    size=max(48,int(min(w,h)*.30))
    size=min(size,w,h)
    integral=np.pad(component.astype(np.int32).cumsum(0).cumsum(1),((1,0),(1,0)))
    def coverage(x0,y0,x1,y1):
        value=integral[y1,x1]-integral[y0,x1]-integral[y1,x0]+integral[y0,x0]
        return float(value/((x1-x0)*(y1-y0)))
    stride=max(12,size//4);candidates=[]
    xs=list(range(0,w-size+1,stride));ys=list(range(0,h-size+1,stride))
    if xs and xs[-1]!=w-size:xs.append(w-size)
    if ys and ys[-1]!=h-size:ys.append(h-size)
    for y0 in ys:
        for x0 in xs:
            cov=coverage(x0,y0,x0+size,y0+size)
            if cov>=.72:
                candidates.append({'box':(x0,y0,x0+size,y0+size),'coverage':cov,'cx':(x0+size/2)/w,'cy':(y0+size/2)/h})
    if not candidates:
        candidates=[{'box':((w-size)//2,(h-size)//2,(w+size)//2,(h+size)//2),'coverage':0,'cx':.5,'cy':.5}]
    selected=[];used=set()
    for ty in (.17,.50,.83):
        for tx in (.17,.50,.83):
            ranked=sorted(enumerate(candidates),key=lambda item:(item[1]['cx']-tx)**2+(item[1]['cy']-ty)**2-.20*item[1]['coverage'])
            choice=next(((i,c) for i,c in ranked if i not in used),ranked[0]);used.add(choice[0]);selected.append(choice[1]['box'])
    boxes=[]
    for x0,y0,x1,y1 in selected:
        boxes.append({'x0':round((offset_x+x0)*sx),'y0':round((offset_y+y0)*sy),'x1':round((offset_x+x1)*sx),'y1':round((offset_y+y1)*sy)})
    return boxes

@torch.no_grad()
def find_wall_views(path):
    with Image.open(path) as source: original=ImageOps.exif_transpose(source).convert('RGB')
    work=original.copy();work.thumbnail((1024,1024),Image.Resampling.LANCZOS)
    inputs=processor(images=work,return_tensors='pt').to(device)
    logits=segmenter(**inputs).logits
    probabilities=F.interpolate(logits,size=(work.height,work.width),mode='bilinear',align_corners=False).softmax(1)
    mask=((probabilities.argmax(1)==wall_id)&(probabilities[:,wall_id]>=.50)).float()[0]
    mask=1-F.max_pool2d(F.pad(1-mask[None,None],(2,2,2,2),value=1),5,stride=1)[0,0]
    binary=mask.cpu().numpy()>=.5
    labels,count=ndimage.label(binary);objects=ndimage.find_objects(labels)
    candidates=[];image_area=work.width*work.height
    for component_id,slices in enumerate(objects,start=1):
        if slices is None:continue
        ys,xs=slices;component=(labels[ys,xs]==component_id);area=int(component.sum())
        if area<image_area*MIN_COMPONENT_AREA:continue
        y0,y1=ys.start,ys.stop;x0,x1=xs.start,xs.stop
        if x1-x0<64 or y1-y0<64:continue
        coverage=area/((x1-x0)*(y1-y0));candidates.append((area,coverage,(x0,y0,x1,y1),component))
    candidates.sort(key=lambda item:item[0],reverse=True)
    sx=original.width/work.width;sy=original.height/work.height;views=[]
    for area,coverage,(x0,y0,x1,y1),component in candidates[:MAX_WALL_VIEWS_PER_IMAGE]:
        mask_data,mask_h,mask_w=encode_small_mask(component)
        local_boxes=select_local_boxes(component,x0,y0,sx,sy)
        views.append({
            'x0':round(x0*sx),'y0':round(y0*sy),'x1':round(x1*sx),'y1':round(y1*sy),
            'wall_coverage':coverage,'mask_data':mask_data,'mask_h':mask_h,'mask_w':mask_w,
            'local_boxes':json.dumps(local_boxes,separators=(',',':')),
        })
    return views

def render_wall_view(path,row):
    with Image.open(path) as source:
        image=ImageOps.exif_transpose(source).convert('RGB').crop((int(row['x0']),int(row['y0']),int(row['x1']),int(row['y1'])))
    mask=decode_mask(row['mask_data'],row['mask_h'],row['mask_w'],image.size)
    return Image.composite(image,Image.new('RGB',image.size,(128,128,128)),mask)

def render_local_views(path,row):
    boxes=json.loads(row['local_boxes']) if isinstance(row['local_boxes'],str) else row['local_boxes']
    with Image.open(path) as source:
        image=ImageOps.exif_transpose(source).convert('RGB')
        return [image.crop((int(b['x0']),int(b['y0']),int(b['x1']),int(b['y1']))) for b in boxes]

view_rows=[];skipped=[]
for index,row in enumerate(source_manifest.to_dict('records'),1):
    try:
        views=find_wall_views(row['path'])
        if not views:skipped.append({**row,'reason':'no_large_wall_region'})
        for view_index,view in enumerate(views):view_rows.append({**row,**view,'view_id':f"{row['source_id']}_{view_index}"})
    except (OSError,ValueError,RuntimeError) as error:skipped.append({**row,'reason':str(error)})
    if index%20==0:print(f'{index}/{len(source_manifest)} sources; wall views={len(view_rows)}',flush=True)
view_manifest=pd.DataFrame(view_rows)
pd.DataFrame(skipped).to_csv(OUT/'skipped_sources.csv',index=False)
(OUT/'patch_manifest.csv').unlink(missing_ok=True)
view_manifest.to_csv(OUT/'wall_view_manifest.csv',index=False)
assert len(view_manifest),'Области стены не найдены'
for split in ['train','val','test']:assert set(view_manifest[view_manifest.split==split].label)==set(classes),f'В {split} пропал класс'
assert view_manifest.groupby('group_id').split.nunique().max()==1
display(pd.crosstab(view_manifest.label,view_manifest.split).reindex(columns=['train','val','test']))
print('Wall views:',len(view_manifest),'Skipped sources:',len(skipped))
del segmenter
if device.type=='mps':torch.mps.empty_cache()
# Out:
# Warning: You are sending unauthenticated requests to the HF Hub. Please set a HF_TOKEN to enable higher rate limits and faster downloads.
# Loading weights:   0%|          | 0/208 [00:00<?, ?it/s]
# 20/780 sources; wall views=20
# 40/780 sources; wall views=43
# 60/780 sources; wall views=66
# 80/780 sources; wall views=86
# 100/780 sources; wall views=107
# 120/780 sources; wall views=130
# 140/780 sources; wall views=152
# 160/780 sources; wall views=173
# 180/780 sources; wall views=197
# 200/780 sources; wall views=219
# 220/780 sources; wall views=242
# 240/780 sources; wall views=263
# 260/780 sources; wall views=287
# 280/780 sources; wall views=310
# 300/780 sources; wall views=333
# 320/780 sources; wall views=355
# 340/780 sources; wall views=380
# 360/780 sources; wall views=408
# 380/780 sources; wall views=433
# 400/780 sources; wall views=460
# 420/780 sources; wall views=484
# 440/780 sources; wall views=509
# 460/780 sources; wall views=530
# 480/780 sources; wall views=552
# 500/780 sources; wall views=575
# 520/780 sources; wall views=597
# 540/780 sources; wall views=622
# 560/780 sources; wall views=644
# 580/780 sources; wall views=665
# 600/780 sources; wall views=688
# 620/780 sources; wall views=709
# 640/780 sources; wall views=731
# 660/780 sources; wall views=754
# 680/780 sources; wall views=761
# 700/780 sources; wall views=788
# 720/780 sources; wall views=816
# 740/780 sources; wall views=842
# 760/780 sources; wall views=869
# 780/780 sources; wall views=895
# split                        train  val  test
# label
# bare_unfinished_wall            94   28    23
# exposed_drywall                 85   22    25
# rigid_decorative_cladding      117   20    28
# tile                            99   27    20
# unfinished_plaster_or_putty    126   19    19
# wallpaper                      122   12     9
# Wall views: 895 Skipped sources: 20

# %% [markdown]
# ## 3. Проверка двух масштабов
#
# Слева показана вся замаскированная стена, справа — один из девяти участков сетки. Девять участков совместно покрывают всю стену.

# %%
PREVIEW_CLASS='wallpaper'
preview=view_manifest[(view_manifest.label==PREVIEW_CLASS)&(view_manifest.split=='train')].head(6)
fig,axes=plt.subplots(3,4,figsize=(14,11));axes=axes.flatten()
for ax in axes:ax.axis('off')
for i,row in enumerate(preview.to_dict('records')):
    global_image=render_wall_view(row['path'],row);local_image=render_local_views(row['path'],row)[0]
    axes[2*i].imshow(global_image);axes[2*i].set_title('Вся стена');axes[2*i].axis('off')
    axes[2*i+1].imshow(local_image);axes[2*i+1].set_title('Локальная фактура');axes[2*i+1].axis('off')
plt.tight_layout();plt.show()

# %% [markdown]
# ## 4. DINOv2, attention и отдельная проверка гипсокартона
#
# DINOv2 остаётся замороженным. Глобальный признак стены, attention-представление девяти участков и max-pooled представление объединяются. Вторая голова отдельно обучается отличать `exposed_drywall` от остальных классов.

# %%
DINO_NAME='facebook/dinov2-small'
DINO_BATCH_VIEWS=4
GLOBAL_DINO_SIZE=448
LOCAL_DINO_SIZE=224
dino_processor=AutoImageProcessor.from_pretrained(DINO_NAME)
dino_model=AutoModel.from_pretrained(DINO_NAME).to(device).eval()
for parameter in dino_model.parameters():parameter.requires_grad=False

records=view_manifest.to_dict('records');global_batches=[];local_batches=[]
with torch.no_grad():
    for start in range(0,len(records),DINO_BATCH_VIEWS):
        batch_rows=records[start:start+DINO_BATCH_VIEWS]
        global_images=[render_wall_view(row['path'],row) for row in batch_rows]
        local_images=[image for row in batch_rows for image in render_local_views(row['path'],row)]
        global_inputs=dino_processor(images=global_images,return_tensors='pt',do_resize=True,size={'height':GLOBAL_DINO_SIZE,'width':GLOBAL_DINO_SIZE},do_center_crop=False).to(device)
        local_inputs=dino_processor(images=local_images,return_tensors='pt',do_resize=True,size={'height':LOCAL_DINO_SIZE,'width':LOCAL_DINO_SIZE},do_center_crop=False).to(device)
        global_cls=dino_model(**global_inputs).last_hidden_state[:,0].cpu()
        local_cls=dino_model(**local_inputs).last_hidden_state[:,0].cpu().reshape(len(batch_rows),LOCAL_VIEWS_PER_WALL,-1)
        global_batches.append(global_cls);local_batches.append(local_cls)
        if start%40==0:print(f'DINOv2: {min(start+len(batch_rows),len(records))}/{len(records)} стен',flush=True)

global_features=torch.cat(global_batches);local_features=torch.cat(local_batches)
labels=torch.tensor([classes.index(row['label']) for row in records],dtype=torch.long)
split_names=np.array([row['split'] for row in records]);source_ids=np.array([row['source_id'] for row in records]);view_ids=np.array([row['view_id'] for row in records])
np.savez_compressed(OUT/'dinov2_embeddings.npz',global_features=global_features.numpy(),local_features=local_features.numpy(),labels=labels.numpy(),splits=split_names,source_ids=source_ids,view_ids=view_ids)
print('Global:',tuple(global_features.shape),'Local:',tuple(local_features.shape))

class EmbeddingDataset(Dataset):
    def __init__(self,indices):self.indices=np.asarray(indices)
    def __len__(self):return len(self.indices)
    def __getitem__(self,index):
        real=int(self.indices[index]);return global_features[real],local_features[real],labels[real],source_ids[real],view_ids[real]

indices={split:np.where(split_names==split)[0] for split in ['train','val','test']}
train_labels=labels[indices['train']].numpy();train_counts=np.bincount(train_labels,minlength=len(classes));train_weights=1.0/train_counts[train_labels]
train_sampler=WeightedRandomSampler(torch.as_tensor(train_weights,dtype=torch.double),len(train_weights),replacement=True)
print('Train views before balancing:',dict(zip(classes,train_counts.tolist())))
loaders={
    'train':DataLoader(EmbeddingDataset(indices['train']),batch_size=32,sampler=train_sampler,num_workers=0),
    'val':DataLoader(EmbeddingDataset(indices['val']),batch_size=64,shuffle=False,num_workers=0),
    'test':DataLoader(EmbeddingDataset(indices['test']),batch_size=64,shuffle=False,num_workers=0),
}

class SeamAwareClassifier(torch.nn.Module):
    def __init__(self,feature_dim,num_classes):
        super().__init__()
        self.attention=torch.nn.Sequential(torch.nn.Linear(feature_dim,128),torch.nn.Tanh(),torch.nn.Linear(128,1))
        fused_dim=feature_dim*3
        self.shared=torch.nn.Sequential(torch.nn.LayerNorm(fused_dim),torch.nn.Linear(fused_dim,384),torch.nn.GELU(),torch.nn.Dropout(.30))
        self.class_head=torch.nn.Linear(384,num_classes)
        self.drywall_head=torch.nn.Linear(384,2)
    def forward(self,global_embedding,local_embeddings):
        attention_weights=self.attention(local_embeddings).squeeze(-1).softmax(1)
        attended=(local_embeddings*attention_weights.unsqueeze(-1)).sum(1)
        maximum=local_embeddings.max(1).values
        shared=self.shared(torch.cat([global_embedding,attended,maximum],dim=1))
        return self.class_head(shared),self.drywall_head(shared),attention_weights

model=SeamAwareClassifier(global_features.shape[1],len(classes)).to(device)
criterion=torch.nn.CrossEntropyLoss();optimizer=torch.optim.AdamW(model.parameters(),lr=3e-4,weight_decay=1e-3)
DRYWALL_INDEX=classes.index('exposed_drywall');DRYWALL_LOSS_WEIGHT=.6

def combined_probabilities(class_logits,drywall_logits):
    class_log_probs=class_logits.log_softmax(1);drywall_log_probs=drywall_logits.log_softmax(1)
    combined=class_log_probs.clone();combined[:,DRYWALL_INDEX]+=drywall_log_probs[:,1]
    mask=torch.ones(len(classes),dtype=torch.bool,device=combined.device);mask[DRYWALL_INDEX]=False
    combined[:,mask]+=drywall_log_probs[:,0,None]
    return combined.softmax(1)

del dino_model
if device.type=='mps':torch.mps.empty_cache()
# Out:
# Loading weights:   0%|          | 0/223 [00:00<?, ?it/s]
# DINOv2: 4/895 стен
# DINOv2: 44/895 стен
# DINOv2: 84/895 стен
# DINOv2: 124/895 стен
# DINOv2: 164/895 стен
# DINOv2: 204/895 стен
# DINOv2: 244/895 стен
# DINOv2: 284/895 стен
# DINOv2: 324/895 стен
# DINOv2: 364/895 стен
# DINOv2: 404/895 стен
# DINOv2: 444/895 стен
# DINOv2: 484/895 стен
# DINOv2: 524/895 стен
# DINOv2: 564/895 стен
# DINOv2: 604/895 стен
# DINOv2: 644/895 стен
# DINOv2: 684/895 стен
# DINOv2: 724/895 стен
# DINOv2: 764/895 стен
# DINOv2: 804/895 стен
# DINOv2: 844/895 стен
# DINOv2: 884/895 стен
# Global: (895, 384) Local: (895, 9, 384)
# Train views before balancing: {'bare_unfinished_wall': 94, 'exposed_drywall': 85, 'rigid_decorative_cladding': 117, 'tile': 99, 'unfinished_plaster_or_putty': 126, 'wallpaper': 122}

# %%
def run_epoch(loader,training=False):
    model.train(training);loss_sum=correct=count=0;all_labels=[];all_predictions=[]
    for global_batch,local_batch,batch_labels,_,_ in loader:
        global_batch,local_batch,batch_labels=global_batch.to(device),local_batch.to(device),batch_labels.to(device)
        drywall_targets=(batch_labels==DRYWALL_INDEX).long()
        if training:optimizer.zero_grad()
        with torch.set_grad_enabled(training):
            class_logits,drywall_logits,_=model(global_batch,local_batch)
            loss=criterion(class_logits,batch_labels)+DRYWALL_LOSS_WEIGHT*criterion(drywall_logits,drywall_targets)
            if training:loss.backward();optimizer.step()
        probabilities=combined_probabilities(class_logits,drywall_logits);predictions=probabilities.argmax(1)
        loss_sum+=loss.item()*len(batch_labels);correct+=(predictions==batch_labels).sum().item();count+=len(batch_labels)
        all_labels.extend(batch_labels.detach().cpu().tolist());all_predictions.extend(predictions.detach().cpu().tolist())
    return loss_sum/count,correct/count,f1_score(all_labels,all_predictions,average='macro',zero_division=0)

best_f1=-1.0;stale=0;history=[]
for epoch in range(60):
    train_loss,train_acc,train_f1=run_epoch(loaders['train'],True);val_loss,val_acc,val_f1=run_epoch(loaders['val'])
    row={'epoch':epoch+1,'train_loss':train_loss,'train_acc':train_acc,'train_macro_f1':train_f1,'val_loss':val_loss,'val_acc':val_acc,'val_macro_f1':val_f1};history.append(row)
    print(f"{epoch+1}/60 train={train_acc:.3f} train_f1={train_f1:.3f} val={val_acc:.3f} val_f1={val_f1:.3f} val_loss={val_loss:.3f}")
    checkpoint={'state_dict':{k:v.detach().cpu().clone() for k,v in model.state_dict().items()},'classes':classes,'architecture':'dinov2_seam_aware_attention','feature_size':global_features.shape[1],'local_views':LOCAL_VIEWS_PER_WALL,'task':'wall_classifier','epoch':epoch+1,'val_loss':val_loss,'val_acc':val_acc,'val_macro_f1':val_f1}
    if val_f1>best_f1+1e-4:best_f1=val_f1;stale=0;torch.save(checkpoint,OUT/'best.pt')
    else:stale+=1
    pd.DataFrame(history).to_csv(OUT/'history.csv',index=False)
    if stale>=10:print('Ранняя остановка по val_macro_f1');break
# Out:
# 1/60 train=0.656 train_f1=0.630 val=0.906 val_f1=0.891 val_loss=0.470
# 2/60 train=0.896 train_f1=0.895 val=0.938 val_f1=0.931 val_loss=0.225
# 3/60 train=0.936 train_f1=0.938 val=0.930 val_f1=0.920 val_loss=0.224
# 4/60 train=0.942 train_f1=0.943 val=0.945 val_f1=0.938 val_loss=0.216
# 5/60 train=0.966 train_f1=0.966 val=0.953 val_f1=0.952 val_loss=0.190
# 6/60 train=0.975 train_f1=0.975 val=0.938 val_f1=0.929 val_loss=0.212
# 7/60 train=0.977 train_f1=0.976 val=0.969 val_f1=0.968 val_loss=0.172
# 8/60 train=0.992 train_f1=0.992 val=0.961 val_f1=0.959 val_loss=0.165
# 9/60 train=0.997 train_f1=0.997 val=0.953 val_f1=0.952 val_loss=0.160
# 10/60 train=0.997 train_f1=0.997 val=0.945 val_f1=0.945 val_loss=0.161
# 11/60 train=1.000 train_f1=1.000 val=0.961 val_f1=0.959 val_loss=0.161
# 12/60 train=0.998 train_f1=0.999 val=0.930 val_f1=0.923 val_loss=0.177
# 13/60 train=0.998 train_f1=0.999 val=0.938 val_f1=0.935 val_loss=0.173
# 14/60 train=1.000 train_f1=1.000 val=0.938 val_f1=0.927 val_loss=0.173
# 15/60 train=1.000 train_f1=1.000 val=0.969 val_f1=0.969 val_loss=0.157
# 16/60 train=1.000 train_f1=1.000 val=0.930 val_f1=0.920 val_loss=0.197
# 17/60 train=1.000 train_f1=1.000 val=0.953 val_f1=0.949 val_loss=0.173
# 18/60 train=1.000 train_f1=1.000 val=0.945 val_f1=0.943 val_loss=0.170
# 19/60 train=1.000 train_f1=1.000 val=0.953 val_f1=0.952 val_loss=0.153
# 20/60 train=1.000 train_f1=1.000 val=0.961 val_f1=0.958 val_loss=0.162
# 21/60 train=1.000 train_f1=1.000 val=0.945 val_f1=0.943 val_loss=0.164
# 22/60 train=1.000 train_f1=1.000 val=0.953 val_f1=0.949 val_loss=0.168
# 23/60 train=1.000 train_f1=1.000 val=0.953 val_f1=0.949 val_loss=0.165
# 24/60 train=1.000 train_f1=1.000 val=0.953 val_f1=0.949 val_loss=0.163
# 25/60 train=1.000 train_f1=1.000 val=0.945 val_f1=0.942 val_loss=0.178
# Ранняя остановка по val_macro_f1

# %% [markdown]
# ## 5. Оценка модели со специальной проверкой drywall
#
# Итоговые вероятности объединяют основной классификатор и бинарную голову `drywall / not_drywall`.

# %%
checkpoint=torch.load(OUT/'best.pt',map_location='cpu',weights_only=True);model.load_state_dict(checkpoint['state_dict']);model.eval()
view_truth=[];view_pred=[];prediction_rows=[]
with torch.no_grad():
    for global_batch,local_batch,batch_labels,batch_source_ids,batch_view_ids in loaders['test']:
        class_logits,drywall_logits,attention=model(global_batch.to(device),local_batch.to(device));probabilities=combined_probabilities(class_logits,drywall_logits).cpu();predictions=probabilities.argmax(1)
        view_truth.extend(batch_labels.tolist());view_pred.extend(predictions.tolist())
        for source_id,view_id,label,prob in zip(batch_source_ids,batch_view_ids,batch_labels.tolist(),probabilities):prediction_rows.append({'source_id':source_id,'view_id':view_id,'true_index':label,'probabilities':prob.numpy()})
print('WALL VIEW LEVEL')
view_report=classification_report(view_truth,view_pred,labels=list(range(len(classes))),target_names=classes,zero_division=0);print(view_report)
source_truth=[];source_pred=[]
for source_id,group in pd.DataFrame(prediction_rows).groupby('source_id'):
    probs=np.stack(group.probabilities).mean(0);source_truth.append(int(group.true_index.iloc[0]));source_pred.append(int(probs.argmax()))
print('SOURCE IMAGE LEVEL')
source_report=classification_report(source_truth,source_pred,labels=list(range(len(classes))),target_names=classes,zero_division=0);print(source_report)
summary={'view_accuracy':accuracy_score(view_truth,view_pred),'view_macro_f1':f1_score(view_truth,view_pred,average='macro',zero_division=0),'source_accuracy':accuracy_score(source_truth,source_pred),'source_macro_f1':f1_score(source_truth,source_pred,average='macro',zero_division=0),'test_views':len(view_truth),'test_sources':len(source_truth),'best_epoch':checkpoint['epoch'],'best_val_loss':checkpoint['val_loss'],'best_val_acc':checkpoint['val_acc'],'best_val_macro_f1':checkpoint['val_macro_f1']}
(OUT/'classification_report_views.txt').write_text(view_report);(OUT/'classification_report_sources.txt').write_text(source_report);(OUT/'summary.json').write_text(json.dumps(summary,indent=2));print(summary)
# Out:
# WALL VIEW LEVEL
#                              precision    recall  f1-score   support
#
#        bare_unfinished_wall       1.00      1.00      1.00        23
#             exposed_drywall       0.88      0.92      0.90        25
#   rigid_decorative_cladding       0.95      0.75      0.84        28
#                        tile       0.86      0.95      0.90        20
# unfinished_plaster_or_putty       0.88      0.79      0.83        19
#                   wallpaper       0.57      0.89      0.70         9
#
#                    accuracy                           0.88       124
#                   macro avg       0.86      0.88      0.86       124
#                weighted avg       0.90      0.88      0.88       124
#
# SOURCE IMAGE LEVEL
#                              precision    recall  f1-score   support
#
#        bare_unfinished_wall       1.00      1.00      1.00        22
#             exposed_drywall       0.87      0.95      0.91        21
#   rigid_decorative_cladding       0.95      0.83      0.88        23
#                        tile       0.85      0.94      0.89        18
# unfinished_plaster_or_putty       0.88      0.83      0.86        18
#                   wallpaper       0.83      0.83      0.83         6
#
#                    accuracy                           0.91       108
#                   macro avg       0.90      0.90      0.90       108
#                weighted avg       0.91      0.91      0.91       108
#
# {'view_accuracy': 0.8790322580645161, 'view_macro_f1': 0.8626180327203343, 'source_accuracy': 0.9074074074074074, 'source_macro_f1': 0.8963374786508201, 'test_views': 124, 'test_sources': 108, 'best_epoch': 15, 'best_val_loss': 0.15678240358829498, 'best_val_acc': 0.96875, 'best_val_macro_f1': 0.9692198146545973}

# %% [markdown]
# ## 6. Применение к новому фото
#
# Помимо четырёх вероятностей выводится `drywall_evidence` — вероятность наличия визуальных признаков листового гипсокартона.

# %%
IMAGE_PATH=PROJECT/'data/raw_photo_sample/fba67c5c560341c8846b3ac23f6d9ec3.webp';MIN_CONFIDENCE=.45
inference_processor=AutoImageProcessor.from_pretrained(segmenter_name);inference_segmenter=SegformerForSemanticSegmentation.from_pretrained(segmenter_name).to(device).eval()
inference_wall_id=next(int(k) for k,v in inference_segmenter.config.id2label.items() if v=='wall');processor,segmenter,wall_id=inference_processor,inference_segmenter,inference_wall_id
views=find_wall_views(IMAGE_PATH);assert views,'На фото не найдены области стены'
dino_processor=AutoImageProcessor.from_pretrained(DINO_NAME);dino_model=AutoModel.from_pretrained(DINO_NAME).to(device).eval()
global_images=[render_wall_view(IMAGE_PATH,view) for view in views];local_images=[image for view in views for image in render_local_views(IMAGE_PATH,view)]
with torch.no_grad():
    global_inputs=dino_processor(images=global_images,return_tensors='pt',do_resize=True,size={'height':GLOBAL_DINO_SIZE,'width':GLOBAL_DINO_SIZE},do_center_crop=False).to(device)
    local_inputs=dino_processor(images=local_images,return_tensors='pt',do_resize=True,size={'height':LOCAL_DINO_SIZE,'width':LOCAL_DINO_SIZE},do_center_crop=False).to(device)
    global_embedding=dino_model(**global_inputs).last_hidden_state[:,0]
    local_embedding=dino_model(**local_inputs).last_hidden_state[:,0].reshape(len(views),LOCAL_VIEWS_PER_WALL,-1)
    class_logits,drywall_logits,attention=model(global_embedding,local_embedding)
    probs=combined_probabilities(class_logits,drywall_logits).cpu().numpy();drywall_evidence=drywall_logits.softmax(1)[:,1].cpu().numpy();attention=attention.cpu().numpy()
predictions=[]
for view,prob,drywall_prob,weights in zip(views,probs,drywall_evidence,attention):
    index=int(prob.argmax());confidence=float(prob[index]);public_view={k:v for k,v in view.items() if k not in {'mask_data','local_boxes'}}
    predictions.append({**public_view,'material':classes[index] if confidence>=MIN_CONFIDENCE else 'uncertain','top_candidate':classes[index],'confidence':round(confidence,3),'drywall_evidence':round(float(drywall_prob),3),'probabilities':{name:round(float(value),3) for name,value in zip(classes,prob)},'local_attention':[round(float(value),3) for value in weights]})
print(json.dumps({'image':str(IMAGE_PATH),'walls':predictions},ensure_ascii=False,indent=2))
fig,axes=plt.subplots(len(views),1+LOCAL_VIEWS_PER_WALL,figsize=(3*(1+LOCAL_VIEWS_PER_WALL),3*len(views)))
if len(views)==1:axes=np.array([axes])
for row,(view,prediction) in enumerate(zip(views,predictions)):
    axes[row,0].imshow(render_wall_view(IMAGE_PATH,view));axes[row,0].set_title(f"{prediction['top_candidate']} {prediction['confidence']:.1%}\ndrywall {prediction['drywall_evidence']:.1%}");axes[row,0].axis('off')
    for column,(image,weight) in enumerate(zip(render_local_views(IMAGE_PATH,view),prediction['local_attention']),start=1):axes[row,column].imshow(image);axes[row,column].set_title(f'{column}: attn {weight:.2f}');axes[row,column].axis('off')
plt.tight_layout();plt.show()
# Out:
# Loading weights:   0%|          | 0/208 [00:00<?, ?it/s]
# Loading weights:   0%|          | 0/223 [00:00<?, ?it/s]
# {
#   "image": "/Users/himynameisartem/Documents/Development/ML/Renovation_calculator_CV/data/raw_photo_sample/fba67c5c560341c8846b3ac23f6d9ec3.webp",
#   "walls": [
#     {
#       "x0": 2,
#       "y0": 2,
#       "x1": 958,
#       "y1": 638,
#       "wall_coverage": 0.5127134812241783,
#       "mask_h": 106,
#       "mask_w": 160,
#       "material": "bare_unfinished_wall",
#       "top_candidate": "bare_unfinished_wall",
#       "confidence": 0.999,
#       "drywall_evidence": 0.002,
#       "probabilities": {
#         "bare_unfinished_wall": 0.999,
#         "exposed_drywall": 0.0,
#         "rigid_decorative_cladding": 0.0,
#         "tile": 0.0,
#         "unfinished_plaster_or_putty": 0.001,
#         "wallpaper": 0.0
#       },
#       "local_attention": [
#         0.139,
#         0.013,
#         0.061,
#         0.233,
#         0.055,
#         0.04,
#         0.064,
#         0.262,
#         0.132
#       ]
#     }
#   ]
# }

# %% [markdown]
# ## 7. Внешняя проверка на папке `data/dataset/test`
#
# Эти фотографии не участвуют в train/validation/test-разделении датасета. Для каждого изображения показывается исходный кадр и до трёх найденных областей стены с предсказанием модели.

# %%
TEST_DIR = PROJECT / 'data/dataset/test'
test_extensions = {'.jpg', '.jpeg', '.png', '.webp', '.bmp', '.tif', '.tiff'}
test_paths = sorted(path for path in TEST_DIR.iterdir() if path.is_file() and path.suffix.lower() in test_extensions)
assert test_paths, f'В {TEST_DIR} нет изображений'

@torch.no_grad()
def predict_external_image(image_path):
    views = find_wall_views(image_path)
    if not views:
        return [], []

    global_images = [render_wall_view(image_path, view) for view in views]
    local_images = [image for view in views for image in render_local_views(image_path, view)]
    global_inputs = dino_processor(
        images=global_images,
        return_tensors='pt',
        do_resize=True,
        size={'height': GLOBAL_DINO_SIZE, 'width': GLOBAL_DINO_SIZE},
        do_center_crop=False,
    ).to(device)
    local_inputs = dino_processor(
        images=local_images,
        return_tensors='pt',
        do_resize=True,
        size={'height': LOCAL_DINO_SIZE, 'width': LOCAL_DINO_SIZE},
        do_center_crop=False,
    ).to(device)
    global_embedding = dino_model(**global_inputs).last_hidden_state[:, 0]
    local_embedding = dino_model(**local_inputs).last_hidden_state[:, 0].reshape(
        len(views), LOCAL_VIEWS_PER_WALL, -1
    )
    class_logits, drywall_logits, _ = model(global_embedding, local_embedding)
    probabilities = combined_probabilities(class_logits, drywall_logits).cpu().numpy()

    predictions = []
    for wall_index, (view, probability) in enumerate(zip(views, probabilities), start=1):
        class_index = int(probability.argmax())
        confidence = float(probability[class_index])
        predictions.append({
            'image': image_path.name,
            'wall': wall_index,
            'prediction': classes[class_index] if confidence >= MIN_CONFIDENCE else 'uncertain',
            'top_candidate': classes[class_index],
            'confidence': confidence,
            **{f'p_{name}': float(value) for name, value in zip(classes, probability)},
        })
    return views, predictions

external_test_rows = []
external_test_results = []
for image_path in test_paths:
    try:
        views, predictions = predict_external_image(image_path)
        external_test_rows.extend(predictions)
        external_test_results.append((image_path, views, predictions, None))
    except (OSError, ValueError, RuntimeError) as error:
        external_test_results.append((image_path, [], [], str(error)))

external_test = pd.DataFrame(external_test_rows)
if len(external_test):
    display(external_test[['image', 'wall', 'prediction', 'top_candidate', 'confidence']].style.format({'confidence': '{:.1%}'}))
else:
    print('Ни на одном тестовом изображении не найдены области стены')

PAGE_SIZE = 4
for page_start in range(0, len(external_test_results), PAGE_SIZE):
    page = external_test_results[page_start:page_start + PAGE_SIZE]
    fig, axes = plt.subplots(len(page), 1 + MAX_WALL_VIEWS_PER_IMAGE, figsize=(16, 4 * len(page)))
    if len(page) == 1:
        axes = np.array([axes])
    for row_index, (image_path, views, predictions, error) in enumerate(page):
        with Image.open(image_path) as source:
            axes[row_index, 0].imshow(ImageOps.exif_transpose(source).convert('RGB'))
        axes[row_index, 0].set_title(image_path.name)
        axes[row_index, 0].axis('off')
        for column in range(MAX_WALL_VIEWS_PER_IMAGE):
            axis = axes[row_index, column + 1]
            axis.axis('off')
            if column < len(views):
                prediction = predictions[column]
                axis.imshow(render_wall_view(image_path, views[column]))
                axis.set_title(
                    f"Стена {column + 1}: {prediction['prediction']}\n"
                    f"{prediction['confidence']:.1%}"
                )
            elif column == 0 and error:
                axis.set_title(f'Ошибка: {error}')
            elif column == 0 and not views:
                axis.set_title('Стена не найдена')
    plt.tight_layout()
    plt.show()

print(f'Проверено изображений: {len(test_paths)}; найдено областей стены: {len(external_test_rows)}')
# Out:
# <style type="text/css">
# </style>
# <table id="T_7aa5a">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_7aa5a_level0_col0" class="col_heading level0 col0" >image</th>
#       <th id="T_7aa5a_level0_col1" class="col_heading level0 col1" >wall</th>
#       <th id="T_7aa5a_level0_col2" class="col_heading level0 col2" >prediction</th>
#       <th id="T_7aa5a_level0_col3" class="col_heading level0 col3" >top_candidate</th>
#       <th id="T_7aa5a_level0_col4" class="col_heading level0 col4" >confidence</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_7aa5a_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_7aa5a_row0_col0" class="data row0 col0" >630-2_1680531410.jpg</td>
#       <td id="T_7aa5a_row0_col1" class="data row0 col1" >1</td>
#       <td id="T_7aa5a_row0_col2" class="data row0 col2" >exposed_drywall</td>
#       <td id="T_7aa5a_row0_col3" class="data row0 col3" >exposed_drywall</td>
#       <td id="T_7aa5a_row0_col4" class="data row0 col4" >100.0%</td>
#     </tr>
#     <tr>
#       <th id="T_7aa5a_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_7aa5a_row1_col0" class="data row1 col0" >7a3e3f0d53e7f120ecd9e1486819de8f41689.jpg</td>
#       <td id="T_7aa5a_row1_col1" class="data row1 col1" >1</td>
#       <td id="T_7aa5a_row1_col2" class="data row1 col2" >bare_unfinished_wall</td>
#       <td id="T_7aa5a_row1_col3" class="data row1 col3" >bare_unfinished_wall</td>
#       <td id="T_7aa5a_row1_col4" class="data row1 col4" >100.0%</td>
#     </tr>
#     <tr>
#       <th id="T_7aa5a_level0_row2" class="row_heading level0 row2" >2</th>
#       <td id="T_7aa5a_row2_col0" class="data row2 col0" >86cd0c3b08816019855db1127e03da61.jpg</td>
#       <td id="T_7aa5a_row2_col1" class="data row2 col1" >1</td>
#       <td id="T_7aa5a_row2_col2" class="data row2 col2" >bare_unfinished_wall</td>
#       <td id="T_7aa5a_row2_col3" class="data row2 col3" >bare_unfinished_wall</td>
#       <td id="T_7aa5a_row2_col4" class="data row2 col4" >58.8%</td>
#     </tr>
#     <tr>
#       <th id="T_7aa5a_level0_row3" class="row_heading level0 row3" >3</th>
#       <td id="T_7aa5a_row3_col0" class="data row3 col0" >Chado_42.jpg</td>
#       <td id="T_7aa5a_row3_col1" class="data row3 col1" >1</td>
#       <td id="T_7aa5a_row3_col2" class="data row3 col2" >rigid_decorative_cladding</td>
#       <td id="T_7aa5a_row3_col3" class="data row3 col3" >rigid_decorative_cladding</td>
#       <td id="T_7aa5a_row3_col4" class="data row3 col4" >100.0%</td>
#     </tr>
#     <tr>
#       <th id="T_7aa5a_level0_row4" class="row_heading level0 row4" >4</th>
#       <td id="T_7aa5a_row4_col0" class="data row4 col0" >chernovaya-otdelka.jpg</td>
#       <td id="T_7aa5a_row4_col1" class="data row4 col1" >1</td>
#       <td id="T_7aa5a_row4_col2" class="data row4 col2" >unfinished_plaster_or_putty</td>
#       <td id="T_7aa5a_row4_col3" class="data row4 col3" >unfinished_plaster_or_putty</td>
#       <td id="T_7aa5a_row4_col4" class="data row4 col4" >99.9%</td>
#     </tr>
#     <tr>
#       <th id="T_7aa5a_level0_row5" class="row_heading level0 row5" >5</th>
#       <td id="T_7aa5a_row5_col0" class="data row5 col0" >images-10.jpeg</td>
#       <td id="T_7aa5a_row5_col1" class="data row5 col1" >1</td>
#       <td id="T_7aa5a_row5_col2" class="data row5 col2" >tile</td>
#       <td id="T_7aa5a_row5_col3" class="data row5 col3" >tile</td>
#       <td id="T_7aa5a_row5_col4" class="data row5 col4" >99.2%</td>
#     </tr>
#     <tr>
#       <th id="T_7aa5a_level0_row6" class="row_heading level0 row6" >6</th>
#       <td id="T_7aa5a_row6_col0" class="data row6 col0" >images-11.jpeg</td>
#       <td id="T_7aa5a_row6_col1" class="data row6 col1" >1</td>
#       <td id="T_7aa5a_row6_col2" class="data row6 col2" >wallpaper</td>
#       <td id="T_7aa5a_row6_col3" class="data row6 col3" >wallpaper</td>
#       <td id="T_7aa5a_row6_col4" class="data row6 col4" >57.2%</td>
#     </tr>
#     <tr>
#       <th id="T_7aa5a_level0_row7" class="row_heading level0 row7" >7</th>
#       <td id="T_7aa5a_row7_col0" class="data row7 col0" >images-12.jpeg</td>
#       <td id="T_7aa5a_row7_col1" class="data row7 col1" >1</td>
#       <td id="T_7aa5a_row7_col2" class="data row7 col2" >rigid_decorative_cladding</td>
#       <td id="T_7aa5a_row7_col3" class="data row7 col3" >rigid_decorative_cladding</td>
#       <td id="T_7aa5a_row7_col4" class="data row7 col4" >98.7%</td>
#     </tr>
#     <tr>
#       <th id="T_7aa5a_level0_row8" class="row_heading level0 row8" >8</th>
#       <td id="T_7aa5a_row8_col0" class="data row8 col0" >images-13.jpeg</td>
#       <td id="T_7aa5a_row8_col1" class="data row8 col1" >1</td>
#       <td id="T_7aa5a_row8_col2" class="data row8 col2" >rigid_decorative_cladding</td>
#       <td id="T_7aa5a_row8_col3" class="data row8 col3" >rigid_decorative_cladding</td>
#       <td id="T_7aa5a_row8_col4" class="data row8 col4" >100.0%</td>
#     </tr>
#     <tr>
#       <th id="T_7aa5a_level0_row9" class="row_heading level0 row9" >9</th>
#       <td id="T_7aa5a_row9_col0" class="data row9 col0" >images-2.jpeg</td>
#       <td id="T_7aa5a_row9_col1" class="data row9 col1" >1</td>
#       <td id="T_7aa5a_row9_col2" class="data row9 col2" >bare_unfinished_wall</td>
#       <td id="T_7aa5a_row9_col3" class="data row9 col3" >bare_unfinished_wall</td>
#       <td id="T_7aa5a_row9_col4" class="data row9 col4" >99.7%</td>
#     </tr>
#     <tr>
#       <th id="T_7aa5a_level0_row10" class="row_heading level0 row10" >10</th>
#       <td id="T_7aa5a_row10_col0" class="data row10 col0" >images-3.jpeg</td>
#       <td id="T_7aa5a_row10_col1" class="data row10 col1" >1</td>
#       <td id="T_7aa5a_row10_col2" class="data row10 col2" >bare_unfinished_wall</td>
#       <td id="T_7aa5a_row10_col3" class="data row10 col3" >bare_unfinished_wall</td>
#       <td id="T_7aa5a_row10_col4" class="data row10 col4" >99.9%</td>
#     </tr>
#     <tr>
#       <th id="T_7aa5a_level0_row11" class="row_heading level0 row11" >11</th>
#       <td id="T_7aa5a_row11_col0" class="data row11 col0" >images-4.jpeg</td>
#       <td id="T_7aa5a_row11_col1" class="data row11 col1" >1</td>
#       <td id="T_7aa5a_row11_col2" class="data row11 col2" >wallpaper</td>
#       <td id="T_7aa5a_row11_col3" class="data row11 col3" >wallpaper</td>
#       <td id="T_7aa5a_row11_col4" class="data row11 col4" >99.9%</td>
#     </tr>
#     <tr>
#       <th id="T_7aa5a_level0_row12" class="row_heading level0 row12" >12</th>
#       <td id="T_7aa5a_row12_col0" class="data row12 col0" >images-5.jpeg</td>
#       <td id="T_7aa5a_row12_col1" class="data row12 col1" >1</td>
#       <td id="T_7aa5a_row12_col2" class="data row12 col2" >rigid_decorative_cladding</td>
#       <td id="T_7aa5a_row12_col3" class="data row12 col3" >rigid_decorative_cladding</td>
#       <td id="T_7aa5a_row12_col4" class="data row12 col4" >59.7%</td>
#     </tr>
#     <tr>
#       <th id="T_7aa5a_level0_row13" class="row_heading level0 row13" >13</th>
#       <td id="T_7aa5a_row13_col0" class="data row13 col0" >images-5.jpeg</td>
#       <td id="T_7aa5a_row13_col1" class="data row13 col1" >2</td>
#       <td id="T_7aa5a_row13_col2" class="data row13 col2" >tile</td>
#       <td id="T_7aa5a_row13_col3" class="data row13 col3" >tile</td>
#       <td id="T_7aa5a_row13_col4" class="data row13 col4" >62.9%</td>
#     </tr>
#     <tr>
#       <th id="T_7aa5a_level0_row14" class="row_heading level0 row14" >14</th>
#       <td id="T_7aa5a_row14_col0" class="data row14 col0" >images-6.jpeg</td>
#       <td id="T_7aa5a_row14_col1" class="data row14 col1" >1</td>
#       <td id="T_7aa5a_row14_col2" class="data row14 col2" >wallpaper</td>
#       <td id="T_7aa5a_row14_col3" class="data row14 col3" >wallpaper</td>
#       <td id="T_7aa5a_row14_col4" class="data row14 col4" >58.1%</td>
#     </tr>
#     <tr>
#       <th id="T_7aa5a_level0_row15" class="row_heading level0 row15" >15</th>
#       <td id="T_7aa5a_row15_col0" class="data row15 col0" >images-7.jpeg</td>
#       <td id="T_7aa5a_row15_col1" class="data row15 col1" >1</td>
#       <td id="T_7aa5a_row15_col2" class="data row15 col2" >wallpaper</td>
#       <td id="T_7aa5a_row15_col3" class="data row15 col3" >wal
# Проверено изображений: 21; найдено областей стены: 24
